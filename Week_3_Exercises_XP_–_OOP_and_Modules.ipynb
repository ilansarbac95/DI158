# %% [markdown]
# <a href="https://colab.research.google.com/github/ilansarbac95/DI158/blob/main/Week_3_Exercises_XP_%E2%80%93_OOP_and_Modules.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ============================================
# Exercises XP – OOP and Modules
# ============================================
# Name: Ilan Sarbac
# Date: October 2025
# Description: My solutions for the OOP & Modules XP exercises
# ============================================


# ---------- EXERCISE 1 : CURRENCIES ----------

# The goal here is to create a Currency class with special (dunder) methods.
# It should handle string representation, integer conversion and addition between currencies.

class Currency:
    def __init__(self, currency, amount):
        self.currency = currency
        self.amount = amount

    # Returns something readable when we print the object
    def __str__(self):
        return f"{self.amount} {self.currency}s"

    # Returns a more "developer-friendly" version
    def __repr__(self):
        return f"{self.amount} {self.currency}s"

    # Allows converting the object to int directly
    def __int__(self):
        return self.amount

    # Add two Currency objects (or a Currency and an int)
    def __add__(self, other):
        if isinstance(other, int):
            return Currency(self.currency, self.amount + other)
        if isinstance(other, Currency):
            if self.currency != other.currency:
                raise TypeError(f"Cannot add between Currency type <{self.currency}> and <{other.currency}>")
            return Currency(self.currency, self.amount + other.amount)
        raise TypeError("Unsupported addition type")

    # Handles +=
    def __iadd__(self, other):
        if isinstance(other, int):
            self.amount += other
            return self
        if isinstance(other, Currency):
            if self.currency != other.currency:
                raise TypeError(f"Cannot add between Currency type <{self.currency}> and <{other.currency}>")
            self.amount += other.amount
            return self
        raise TypeError("Unsupported addition type")


# Quick test area
if __name__ == "__main__":
    print("=== Exercise 1: Currency Class ===")
    c1 = Currency('dollar', 5)
    c2 = Currency('dollar', 10)
    c3 = Currency('shekel', 1)
    c4 = Currency('shekel', 10)

    print(c1)          # 5 dollars
    print(int(c1))     # 5
    print(repr(c1))    # 5 dollars
    print(c1 + 5)      # 10 dollars
    print(c1 + c2)     # 15 dollars
    print(c1)          # 5 dollars
    c1 += 5
    print(c1)          # 10 dollars
    c1 += c2
    print(c1)          # 20 dollars
    # print(c1 + c3)    # Uncomment to see the TypeError


# ---------- EXERCISE 2 : IMPORT ----------

# In this one, we just create a small function that adds two numbers.
# Normally it would be inside a file called func.py, and imported into another script.
# Here I keep everything in the same file to make testing easier.

def sum_two_numbers(a, b):
    result = a + b
    print(f"The sum of {a} and {b} is {result}")
    return result


print("\n=== Exercise 2: Import Function ===")
sum_two_numbers(4, 9)


# ---------- EXERCISE 3 : STRING MODULE ----------

# Here we generate a random string of 5 characters using the string module.

import string
import random

def generate_random_string(length=5):
    letters = string.ascii_letters  # all uppercase + lowercase letters
    random_string = ''.join(random.choice(letters) for _ in range(length))
    return random_string

print("\n=== Exercise 3: String Module ===")
print("Random string of length 5:", generate_random_string())
# Out:
# === Exercise 1: Currency Class ===
# 5 dollars
# 5
# 5 dollars
# 10 dollars
# 15 dollars
# 5 dollars
# 10 dollars
# 20 dollars
#
# === Exercise 2: Import Function ===
# The sum of 4 and 9 is 13
#
# === Exercise 3: String Module ===
# Random string of length 5: IWuNj
