# %% [markdown]
# <a href="https://colab.research.google.com/github/ilansarbac95/DI158/blob/main/Daily_Challenge__NumPy_Pandas_and_M.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import des bibliothèques
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Étape 1 : Génération des données (Températures aléatoires entre -5 et 35°C)
np.random.seed(42)  # pour reproductibilité
temps = np.random.uniform(low=-5, high=35, size=(10, 12))  # 10 villes x 12 mois

# Création du DataFrame
cities = [f'City {i+1}' for i in range(10)]
months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun',
          'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']

df = pd.DataFrame(data=temps, index=cities, columns=months)

# Étape 2 : Analyse des données

# Moyenne annuelle par ville
df['Annual Avg Temp'] = df.mean(axis=1)

# Ville avec température moyenne la plus élevée et la plus basse
hottest_city = df['Annual Avg Temp'].idxmax()
coldest_city = df['Annual Avg Temp'].idxmin()

# Affichage des moyennes
print("🌡️ Moyennes annuelles par ville:")
print(df['Annual Avg Temp'].round(2))

print(f"\n🔥 Ville la plus chaude : {hottest_city} ({df.loc[hottest_city, 'Annual Avg Temp']:.2f} °C)")
print(f"❄️ Ville la plus froide : {coldest_city} ({df.loc[coldest_city, 'Annual Avg Temp']:.2f} °C)")

# Étape 3 : Visualisation
plt.figure(figsize=(12, 6))
for city in cities:
    plt.plot(months, df.loc[city, months], label=city)

plt.title("📈 Monthly Temperature Trends for Each City")
plt.xlabel("Month")
plt.ylabel("Temperature (°C)")
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# 🌡️ Moyennes annuelles par ville:
# City 1     15.64
# City 2      9.57
# City 3     15.53
# City 4     11.14
# City 5     16.62
# City 6     13.82
# City 7     13.19
# City 8     17.61
# City 9     11.32
# City 10    16.41
# Name: Annual Avg Temp, dtype: float64
#
# 🔥 Ville la plus chaude : City 8 (17.61 °C)
# ❄️ Ville la plus froide : City 2 (9.57 °C)
# /tmp/ipython-input-3732027062.py:43: UserWarning: Glyph 128200 (\N{CHART WITH UPWARDS TREND}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 128200 (\N{CHART WITH UPWARDS TREND}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# # Summary of the Analysis
#
# - This simulation generates monthly temperature data for 10 cities, with random values ranging from -5°C to 35°C.
# - The resulting DataFrame includes monthly temperatures and the calculated annual average temperature for each city.
# - The hottest city is **City X**, while the coldest is **City Y**.
# - The visualization clearly highlights seasonal trends and differences in climate across the cities.
